# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras

# %%
data=pd.read_csv(r"C:\Users\moham\OneDrive\Documents\Artificial intelligence( VI Never Delete )\Projects\Internships Projects\Cellula\hotel prediction\Modeling\data.csv")

# %%
data
# Out:
#        meal  parking  room_type  lead_time  market  repeated  canceled_book  \
# 0         2        0          0          5       2         0              0
# 1         0        0          0        211       2         0              0
# 2         2        0          0         48       2         0              0
# 3         0        0          0         34       2         0              0
# 4         0        0          2         83       2         0              0
# ...     ...      ...        ...        ...     ...       ...            ...
# 28419     2        0          0         48       2         0              0
# 28420     0        0          0         34       2         0              0
# 28421     0        0          2         83       2         0              0
# 28422     0        0          0        121       1         0              0
# 28423     0        0          2         44       2         0              0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop('output',axis=1)
y=data['output']

# %%
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,shuffle=True,test_size=0.2,random_state=15)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (22739, 11) (5685, 11) (22739,) (5685,)

# %%
keras_model=keras.models.Sequential([
    keras.layers.Dense(64,activation='sigmoid'),
    keras.layers.Dense(128,activation='sigmoid'),
    keras.layers.Dense(64,activation='sigmoid'),
    keras.layers.Dense(64,activation='sigmoid'),
    keras.layers.Dense(1,activation='sigmoid'),
])

# %%
my_optmizer=tf.keras.optimizers.AdamW()

# %%
keras_model.compile(
    loss="binary_crossentropy",
    optimizer=my_optmizer,
    metrics=['accuracy']
)

# %%
history=keras_model.fit(x_train,y_train,
                        validation_data=(x_test,y_test),
                        epochs=100,
                        batch_size=10,
                        verbose=1,
                        callbacks=[tf.keras.callbacks.EarlyStopping(
                                            patience=10,
                                            monitor='val_accuracy',
                                            restore_best_weights=True)])
# Out:
# Epoch 1/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7603 - loss: 0.4825 - val_accuracy: 0.7706 - val_loss: 0.4839
# Epoch 2/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7758 - loss: 0.4722 - val_accuracy: 0.7891 - val_loss: 0.4711
# Epoch 3/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 2s 996us/step - accuracy: 0.7849 - loss: 0.4573 - val_accuracy: 0.7884 - val_loss: 0.4691
# Epoch 4/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 2s 992us/step - accuracy: 0.7894 - loss: 0.4497 - val_accuracy: 0.7901 - val_loss: 0.4534
# Epoch 5/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 2s 1000us/step - accuracy: 0.7942 - loss: 0.4465 - val_accuracy: 0.7886 - val_loss: 0.4625
# Epoch 6/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 2s 990us/step - accuracy: 0.8011 - loss: 0.4385 - val_accuracy: 0.7856 - val_loss: 0.4635
# Epoch 7/100
# 2274/2274 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7977 - loss: 0.4404 - val_accuracy: 0.7938 - val_loss: 0.4461
# Epoch 8/100
# ...
